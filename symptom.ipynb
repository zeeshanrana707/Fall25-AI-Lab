# %%
import pandas as pd

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv("Symptom-severity.csv")

# %% [markdown]
# #### Top 5 values

# %%
df.head(5)
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %% [markdown]
# #### Last 5 values

# %%
df.tail(5)
# Out:
#                   Symptom  weight
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5

# %% [markdown]
# #### Total Number of rows

# %%
print('rows:', df.shape[0])
# Out:
# rows: 133

# %% [markdown]
# #### Total Number of Columns

# %%
print('columns:', df.shape[1])
# Out:
# columns: 2

# %% [markdown]
# #### Checking the Null values

# %%
df.isnull().sum()
# Out:
# Symptom    0
# weight     0
# dtype: int64

# %% [markdown]
# #### Filling the Null Values with Mean/Median/Mode if any.

# %%
df = df.fillna(df.mean)
# df = df.fillna(df.median)
# df = df.fillna(df.mode)
